# %% [markdown]
# # Praktikum Modul 2 AI

# %% [markdown]
# **Nama : Nur Azka Rahadiansyah**
#
# **NRP : 5027221064**

# %% [markdown]
# - Selamat datang di Praktikum Modul 2, bantu Rendy Atreides dalam menyelesaikan soal soal modul Statistika dan Probabilitas. <br>
# - Jika ada pertanyaan silahkan tanyakan di **#use-ask** discord praktikum.
#
# # Table of Contents
# - [Case A](#A)
#     - [ Soal 1](#1)
# - [Case B](#B)
#     - [ Soal 2](#2)
# - [Case C](#C)
#     - [ Soal 3](#3)
# - [Case D](#D)
#     - [ Soal 4](#4)
#     - [ Soal 5](#5)
# - [ Soal 6](#6)

# %%
# Tambahkan sendiri seperlunya
import numpy as np
import pandas as pd

from scipy.stats import binom

# %% [markdown]
# <a name='A'></a>
# ## Case A
#
# - Rendy Atreides mempunyai penglihatan terhadap musim hujan yang akan datang, karena hal tersebut ada kemungkinan/probabilitas teman dan kerabat nya untuk mendapatkan flu, $P(\text{flu})$
# - Jika orang tersebut mendapatkan **vaksinasi**, maka peluang orang tersebut untuk terjangkit flu **seharusnya** berubah.
#
# - Diberikan data berikut
#
# | Kondisi   | Suhu Rata-rata (°C) | Vaksin | Tidak Vaksin | PDB Regional (dalam Miliar) | Jumlah Hari Libur Nasional | Rata-rata Jam Matahari per Hari |
# |-----------|---------------------|--------|--------------|-----------------------------|----------------------------|---------------------------------|
# | Flu       | 27                  | 200    | 900          | 650                         | 12                         | 6                               |
# | Tidak Flu | 27                  | 4000   | 9000         | 650                         | 12                         | 6                               |

# %% [markdown]
# ---
# <a name='1'></a>
# ### **Soal 1**:
# A. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila telah vaksin? <br>
#
# $$
# \begin{align*}
# P(\text{flu} \ | \ \text{vaksin}) &= ?
# \end{align*}
# $$
#
# B. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila **belum** divaksin?

# %%
n_flu_dan_vaksin = 200
n_flu_dan_tidak_vaksin = 900

n_tidak_flu_dan_vaksin = 4000
n_tidak_flu_dan_tidak_vaksin = 9000

# %% [markdown]
# ### A. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila telah vaksin?

# %%
n_vaksin = n_tidak_flu_dan_vaksin + n_flu_dan_vaksin
#n_vaksin = 4000+200
print(f"Jumlah orang yang divaksin : {n_vaksin}")
p_flu_jika_vaksin = n_flu_dan_vaksin / n_vaksin
#p_flu_jika_vaksin = 200 / 4200
print(f"A. Peluang orang mengalami flu jika sudah vaksin : {p_flu_jika_vaksin:.4f}")
# Out:
# Jumlah orang yang divaksin : 4200
# A. Peluang orang mengalami flu jika sudah vaksin : 0.0476

# %% [markdown]
# Solver:
#
# $$
# \begin{align*}
# P(\text{flu} \ | \ \text{vaksin}) &= \cfrac{n(\text{flu} \cap \text{vaksin})}{n(\text{vaksin})}
# \end{align*}
# $$

# %% [markdown]
# ### B. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila **belum** divaksin?

# %%
n_tidak_vaksin = n_flu_dan_tidak_vaksin + n_tidak_flu_dan_tidak_vaksin
#n_tidak_vaksin = 9900
p_flu_jika_belum_vaksin = n_flu_dan_tidak_vaksin / n_tidak_vaksin
#p_flu_jika_belum_vaksin = 900 / 9900
print(f"Peluang orang mengalami flu jika belum vaksin : {p_flu_jika_belum_vaksin:.4f}")
# Out:
# Peluang orang mengalami flu jika belum vaksin : 0.0909

# %% [markdown]
# **Penjelasan Pengerjaan Soal 1** <br>

# %% [markdown]
# A. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila telah vaksin?
#
# peluang seseorang akan mengidap flu apabila telah vaksin dapat dicari menggunakan rumus yang terdapat pada solver. Dengan mendapatkan **𝑛(vaksin)** sebanyak **4200** maka hasil dari perhitungannya menjadi 0,04761904761904761904761904761905 atau 0,047 atau 0,05.
#
# B. Dari data di atas, berapa peluang seseorang akan mengidap flu apabila belum divaksin?
#
# peluang seseorang akan mengidap flu apabila belum divaksin dapat dicari dengan mengulangi rumus yang terdapat pada solver dan pengerjaannya sama seperti poin A. Dimana rumusnya menjadi :
# $$
# \begin{align*}
# P(\text{flu} \ | \ \text{tidak vaksin}) &= \cfrac{n(\text{flu} \cap \text{tidak vaksin})}{n(\text{tidak vaksin})}
# \end{align*}
# $$
#
# sehingga didapatkan **𝑛(tidak vaksin)** yaitu **9900** dan didapatkan hasil dari penggunaan rumus yaitu 0,09090909090909090909090909090909 atau 0.09 atau 0.1

# %% [markdown]
# <a name='B'></a>
# ## Case B = Pengaruh Cuaca Terhadap Frekuensi Penggunaan Transportasi Umum
#
# - Telah diamati bahwa cuaca memiliki pengaruh terhadap keputusan orang menggunakan transportasi umum. Anda memiliki data historis dari perusahaan transportasi umum yang mencatat jumlah penumpang per hari selama berbagai kondisi cuaca.
#
# - Diberikan data berikut
#
# | Data Operasi       | Pengguna ketika Hujan | Pengguna ketika Cerah | Promo yang berlaku | Zona Tarif |
# |--------------------|-------|-------|--------------------|------------|
# | Grab-bike          | 4     | 475   |Diskon 10%          |Zona 1      |
# | Grab-car           | 185   | 49    |Tidak ada promo     |Zona 2      |

# %% [markdown]
# ---
# <a name='2'></a>
# ### **Soal 2**:
# A. Berapa peluang **orang menggunakan produk grab-bike?** <br>
# B. Berapa peluang **orang menggunakan produk grab-car** jika diketahui **terjadi hujan**<br>
# C. Berapa peluang **orang menggunakan produk grab-car** jika diketahui **hari cerah**<br>
# D. Bagaimana konsep probabilitas bersyarat digunakan untuk menghitung peluang penggunaan produk grab-car ketika diketahui kondisi cuaca (hujan atau cerah), dan mengapa ini penting dalam menganalisis data operasi seperti ini?

# %% [markdown]
# ### A. Berapa peluang **orang menggunakan produk grab-bike?**

# %%
soal_2A = soal_2A = (4+475) / ((4 +475)+(185+49))
#soal_2A = n(grab-bike) / n(grab-bike+grab-car)

print(f"2A. Peluang orang menggunakan produk grab-bike adalah : {soal_2A =:.2f}")
# Out:
# 2A. Peluang orang menggunakan produk grab-bike adalah : soal_2A =0.67

# %% [markdown]
# ### B. Berapa peluang **orang menggunakan produk grab-car** jika diketahui **terjadi hujan**

# %%
Soal_2B = 185 / (185 + 4)
#soal_2B = n(hujan) / n(grab-car ∩ hujan)
print(f"2B. Peluang orang menggunakan produk go-car jika diketahui terjadi hujan adalah : {Soal_2B:.2f}")

# %% [markdown]
# Solver:
#
# $$
# \begin{align*}
# P(\text{A} \ | \ \text{B}) &= \cfrac{P(\text{A} \cap \text{B})}{P(\text{B})}
# \end{align*}
# $$

# %% [markdown]
# ### C. Berapa peluang **orang menggunakan produk grab-car** jika diketahui **hari cerah**

# %%
Soal_2C = 49 / (49 + 475)
#Soal_2C = n(cerah) / n(grab-car ∩ cerah)

print(f"2C. peluang orang menggunakan produk grab-car jika diketahui hari cerah : {Soal_2C:.2f}")

# %% [markdown]
# ### D. Bagaimana konsep probabilitas bersyarat digunakan untuk menghitung peluang penggunaan produk grab-car ketika diketahui kondisi cuaca (hujan atau cerah), dan mengapa ini penting dalam menganalisis data operasi seperti ini?

# %% [markdown]
# D. ...................

# %% [markdown]
# **Penjelasan Pengerjaan Soal 2** <br>

# %% [markdown]
# A. Berapa peluang orang menggunakan produk grab-bike?
# Dapat dicari dengan menggunakan rumus n(grab-bike) / n(grab-bike+grab-car). didapatkan **n(grab-bike+grab-car)** yaitu 713. Lalu hasil dari eksekusi rumus tadi maka didapatkan **479/713** dan di dapatkan nilai 0,67180925666199158485273492286115 atau 0,67 atau 0,7
#
# B. Berapa peluang orang menggunakan produk grab-car jika diketahui terjadi hujan
# Dapat dicari dengan menggunakan rumus n(hujan) / n(grab-car ∩ hujan). didapatkan hasil dari **n(grab-car ∩ hujan)** yaitu 189. lalu hasil dari eksekusi rumus tadi maka didapatkan **185 / 189** dan di dapatkan nilai 0,97883597883597883597883597883598 atau 0.97 atau 1.
#
# C. Berapa peluang orang menggunakan produk grab-car jika diketahui hari cerah
# Dapat dicari dengan menggunakan rumus n(cerah) / n(grab-car ∩ cerah). didapatkan hasil dari **n(grab-car ∩ cerah)** 524 lalu hasil dari eksekusi rumus tadi maka didapatkan **49/524 ** dan di dapatkan nilai 0,09351145038167938931297709923664 atau 0,09 atau 0,1.
#
# D. Bagaimana konsep probabilitas bersyarat digunakan untuk menghitung peluang penggunaan produk grab-car ketika diketahui kondisi cuaca (hujan atau cerah), dan mengapa ini penting dalam menganalisis data operasi seperti ini?
# Konsep probabilitas bersyarat digunakan untuk menghitung peluang seseorang akan menggunakan produk grab-car ketika diketahui kondisi cuaca (hujan atau cerah). Saya meyimpulkan rumus solver dapat digunakan lagi menjadi rumus :
#
# $$P(\text{A}|\text{B}) = \frac{P(\text{A} \cap \text{B})}{P(\text{B})}$$
#
# Dimana A terikat dengan B dalam artian apa yang terjadi pada A bergantung pada hasil dari B. probabilitas untuk menggunakan Grab-car atau Grab-bike bisa dieksekusi dengan menggunakan data lalu menentukan langkah selanjutnya. tujuan lain yaitu untuk meningkatkan efisiensi operasional dan kepuasan pengguna terutama untuk :)

# %% [markdown]
# ---
# <a name='C'></a>
# ### **Case 3**: Sebuah perusahaan IT memiliki dua divisi, Divisi Pengembangan dan Divisi Pemasaran, yang keduanya mempekerjakan para profesional IT. Dalam Divisi Pengembangan, 30% dari pekerja memiliki pengalaman kerja kurang dari 3 tahun, sedangkan di Divisi Pemasaran, 70% dari pekerja memiliki pengalaman kerja kurang dari 3 tahun.
#
# <a name='3'></a>
# ### Soal 3.
# A. Jika seorang pekerja dipilih secara acak dan ternyata memiliki pengalaman kerja kurang dari 3 tahun, berapa probabilitas bahwa pekerja tersebut berasal dari Divisi Pengembangan? <br>
# B. Dengan mempertimbangkan informasi dari Divisi Pengembangan dan Divisi Pemasaran seperti yang diberikan sebelumnya, jika diketahui bahwa sebuah proyek baru memerlukan tim yang terdiri dari pekerja dengan pengalaman kerja kurang dari 3 tahun, dan satu pekerja dipilih secara acak dari keseluruhan pekerja yang memenuhi kriteria ini, berapa rasio antara probabilitas pekerja tersebut berasal dari Divisi Pengembangan terhadap probabilitas pekerja tersebut berasal dari Divisi Pemasaran?

# %% [markdown]
# ### A. Jika seorang pekerja dipilih secara acak dan ternyata memiliki pengalaman kerja kurang dari 3 tahun, berapa probabilitas bahwa pekerja tersebut berasal dari Divisi Pengembangan?

# %%
Soal_3_A = 0.3 * 0.3 / 0.58
#P(<pengembangan|<3tahun)=n(< 3 Tahun∣Pengembangan)×n(Pengembangan) / n(<3tahun)
print(f"3A. Jawaban : {Soal_3_A:.2f}")
# Out:
# 3A. Jawaban : 0.16

# %% [markdown]
# ### B. Rasio probabilitas pekerja berasal dari Divisi Pengembangan terhadap Divisi Pemasaran

# %%
Soal_3_B = 0.3 / 0.7
#n(pengembangan) / n(pemasaran)
print(f"3B. Jawaban : {Soal_3_B:.2f}")
# Out:
# 3B. Jawaban : 0.43

# %% [markdown]
# **Penjelasan Pengerjaan Soal 3** <br>

# %% [markdown]
# A. Jika seorang pekerja dipilih secara acak dan ternyata memiliki pengalaman kerja kurang dari 3 tahun, berapa probabilitas bahwa pekerja tersebut berasal dari Divisi Pengembangan?
#
# saya merumuskan seperti ini P(< pengembangan|<3tahun)=P(< 3 Tahun∣Pengembangan)×P(Pengembangan) / P(<3tahun). Dimana P(Pengembangan)=0.3 (probabilitas bahwa seorang pekerja berasal dari Divisi Pengembangan) lalu P(< 3 Tahun∣Pengembangan)=0.3 (probabilitas bahwa seorang pekerja memiliki pengalaman kurang dari 3 tahun jika berasal dari Divisi Pengembangan). dan P(< 3 Tahun)=0.58 (probabilitas bahwa seorang pekerja memiliki pengalaman kurang dari 3 tahun).
# berikut perhitungan asal P(<3tahun) :
# P(<3tahun) = 0,3 x 0,3 + 0,7 x 0,7 = 0,09 + 0,49 = 0,58
#
# maka didapatkan hasil 0,3 x 0,3 / 0,58 = 0,09 / 0,58 = 0,15517241379310344827586206896552 atau 0.155 atau 15,5% atau 16%
#
# B. Rasio probabilitas pekerja berasal dari Divisi Pengembangan terhadap Divisi Pemasaran
#
# hasil dari Soal_3_B = 0.3 / 0.7 adalah 0,43

# %% [markdown]
# ---
# <a name='D'></a>
# ## **Case C**:
# Sebuah perusahaan memproduksi sekrup dan melakukan inspeksi kualitas sekrup. Perusahaan tersebut menyimpan data inspeksi sekrup cacat dalam file format csv yang kita baca di bawah ini
#
# <a name='4'></a>
# ### **Soal 4**: Berapa peluang sekrup cacat dari data inspeksi perusahaan tersebut <br>
#
# <a name='5'></a>
# ### **Soal 5**: Berapa proporsi banyak kemasan terjual yang harus diganti oleh perusahaan?
#
# Keterangan
# - (1 = Lolos Uji Cacat, 0 = Cacat)
# - Setiap kemasan berisi 10 sekrup
# - Kemasan harus diganti jika terdapat satu atau lebih sekrup cacat di dalamnya.

# %%
# Pastikan file .csv berada pada directory yang sama
df = pd.read_csv("./soal4_defect_test.csv")
df

# %% [markdown]
# ### **Soal 4**: Berapa peluang sekrup cacat dari data inspeksi perusahaan tersebut <br>

# %%
skrupcacat = (df["lolos_uji_cacat"] == 0).value_counts()[True]
Soal_4 =skrupcacat / len(df)
print(f"peluang cacat:{Soal_4}")

# %% [markdown]
# **Penjelasan Pengerjaan Soal 4** <br>

# %% [markdown]
# Berapa peluang sekrup cacat dari data inspeksi perusahaan tersebut?
#
# untuk menemukan peluang skrup maka harus dihitung terlebih dahulu total skrup yang cacat lalu setelah ditemukan hasilnya dibagi dengan total skurp atau bisa dirumuskan sebagai P(ccacat) = n(cacat) / n(ttotal). lalu untuk tambahan menggunakan (df["lolos_uji_cacat"] == 0).value_counts()[True] ini untuk menghitung berapa kali setiap nilai muncul dalam file juga mencari berapa kali nilai True muncul dalam Series boolean yang dihasilkan. sehingga hasil yang didapatkan adalah

# %% [markdown]
# ---
# <a name='5'></a>
# ### **Soal 5**: Berapa probabilitas sebuah kemasan perlu diganti, asumsikan bahwa probabilitas sebuah sekrup cacat adalah 0.01 dan setiap kemasan berisi 10 sekrup?
#
# Clue: $P(X>1)$ bisa dicari dengan
# $$P(X>1) = 1 - P(X=0) - P(X=1)$$

# %%
# from scipy.stats import binom
p = 0.01
n = 10
peluang_0 = binom.pmf(0, n, p)
Soal_5 = 1 - peluang_0
print(Soal_5)

# %% [markdown]
# **Penjelasan Pengerjaan Soal 5** <br>

# %% [markdown]
# dengan clue diatas maka menggunakan distribusi binomial dimana menganggap setiap sekrup dalam kemasan sebagai percobaan Bernoulli dengan probabilitas keberhasilan p(probabilitas sekrup cacat) = 0,01 dan n (jumlah sekrup dalam setiap kemasan)= 10. Dengan kesimpulan bahwa probabilitas sebuah kemasan perlu diganti karena mengandung setidaknya satu skrup cacat adalah sekitar 0.0956 atau sekitar 9.56%

# %% [markdown]
# ---
# <a name='6'></a>
# ### **Soal 6**: Sebuah kompetisi internasional mengevaluasi atlet berdasarkan dua kriteria: skor teknik dan skor artistik. Berikut ini adalah 25 total atlet yang berkompetisi. Juri memberikan penilaian untuk masing-masing atlet berdasarkan kedua kriteria tersebut. Data penilaian telah dikumpulkan sebagai berikut:
#
# | Atlet   | Skor Teknik (X) | Skor Artistik (Y) |
# |---------|-----------------|-------------------|
# | Atlet 1 | 96              | 91                |
# | Atlet 2 | 88              | 87                |
# | Atlet 3 | 92              | 89                |
# | Atlet 4 | 90              | 94                |
# | Atlet 5 | 94              | 90                |
# | Atlet 6 | 89              | 85                |
# | Atlet 7 | 93              | 88                |
# | Atlet 8 | 87              | 92                |
# | Atlet 9 | 95              | 93                |
# | Atlet 10| 91              | 86                |
# | Atlet 11| 90              | 91                |
# | Atlet 12| 92              | 88                |
# | Atlet 13| 89              | 90                |
# | Atlet 14| 96              | 95                |
# | Atlet 15| 88              | 89                |
# |Atlet 20 |	92	            | 91                |
# |Atlet 21 |	89	            | 86                |
# |Atlet 23 |	87	            | 90                |
# |Atlet 24 |	96	            | 95                |
# |Atlet 25 |	88	            | 89                |
#
#
# Hitung <br>
# A. Untuk melihat tingkat kesulitan dari perlombaan ini, hitung nilai exspektasi untuk skor teknikal dan artistik nya <br>
# B. Untuk mengetahui persebaran nilai dari masing-masing atlet, hitung nilai variance untuk kedua skor tersebut <br>
# C. Hitung Covariance Matrix antara skor teknikal dengan skor artistik untuk mengetahui korelasi kedua skor tersebut<br>
#
# **Clue**
# - Hati hati dengan kata kata total, apakah itu sample? atau populasi?

# %%
# Solver soal 6
teknik = np.array([96, 88, 92, 90, 94, 89, 93, 87, 95, 91, 90, 92, 89, 96, 88, 92, 89, 87, 96, 88])
artistik = np.array([91, 87, 89, 94, 90, 85, 88, 92, 93, 86, 91, 88, 90, 95, 89, 91, 86, 90, 95, 89])
# A. Expectation (Nilai Harapan)
expectation_x = np.mean(teknik)
expectation_y = np.mean(artistik)
print(f"Expectation teknik: {expectation_x}, Expectation artistik: {expectation_y}")

# B. Variance (Varians)
variance_x = np.var(teknik)
variance_y = np.var(artistik)
print("variance teknik:", np.var(teknik), "variance artistik:", np.var(artistik))

# C. Covariance Matrix (Matriks Kovarians)
covariance_matrix = np.cov(teknik, artistik)
print("Covariance Matrix:")

# %% [markdown]
# **Penjelasan Pengerjaan Soal 6**

# %% [markdown]
# Pada langkah awal lebih baik untuk array agar memudahkan pengerjaan
#
# A. Untuk melihat tingkat kesulitan dari perlombaan ini, hitung nilai exspektasi untuk skor teknikal dan artistik nya
#
# menggunakan **np.mean** untuk mencari mean dari data lalu didapatkan expectation_teknik sebesar 91,1 dan expectation_artistik sebesar 89,45
#
# B. Untuk mengetahui persebaran nilai dari masing-masing atlet, hitung nilai variance untuk kedua skor tersebut
#
# menggunakan **np.var** untuk mencari var dari data lalu didapatkan variance_teknik sebesar 8,99 atau 9 dan variance_artistik sebesar 7,65.
#
#
# C. Hitung Covariance Matrix antara skor teknikal dengan skor artistik untuk mengetahui korelasi kedua skor tersebut
# menggunakan **np.cov** setelah variable dimasukkan nanti akan keluar hasilnya
#
# :)
